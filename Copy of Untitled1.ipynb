# %%
# @title Default title text
from random import randint # typo fixed here: 'randon' -> 'random'
puan=0
while True:
  secenekler= ["tas" ,"kagıt","makas"]
  #bir liste olustur
  bilgisayar=secenekler[randint(0,2)]
  #bilgisayar: listeden rastgele seç
  kullanıcı = input("tas,kagıt, makas:(bitirmek =herhangi bir harf.) ")
 #kullanıcıdan veri al
  if kullanıcı == bilgisayar: # fixed indentation here
    print("berabere")
  elif kullanıcı== "tas":
    if bilgisayar == "kagıt":
      puan= puan -1
      print("kaybettniz", bilgisayar, kullanıcı, "1 sarar.")
    else:
      puan= puan +1
      print("kazandınız", kullanıcı , bilgisayar , "1 kırar.")
  elif kullanıcı== "kagıt":
    if bilgisayar == "makas":
      puan=puan -1
      print("kaybettiniz", bilgisayar, kullanıcı, "1 keser.") # fixed indentation here
    else:
      puan= puan +1
      print("kazandınız", kullanıcı , bilgisayar , "1 sarar.")
  elif kullanıcı== "makas":
    if bilgisayar == "tas":
      puan=puan -1
      print("kaybettiniz", bilgisayar, kullanıcı, "1 kırar.") # fixed indentation here
    else:
      puan= puan +1
      print("kazandınız", bilgisayar,kullanıcı,"1 sarar.") # fixed typo: 'kazandınız' -> 'kazandınız
      # !apt-get install git
